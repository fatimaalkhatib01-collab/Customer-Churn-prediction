# %% [markdown]
# # Milestone 1: Customer Churn Prediction
# **Name:** Fatima Anwar AlKhatib

# %% [markdown]
# Customer Churn Prediction - Project Proposal
# 1. The Project I Want to Build
# I want to build a machine learning model that predicts customer churn. The model will analyze historical customer data, subscription details, and interaction metrics to classify which customers are most likely to stop using our service.
#
# 2. The Business Problem This Project Responds To
# Acquiring new customers is significantly more expensive than retaining existing ones. The business is currently losing revenue due to undetected customer churn. We need a proactive approach to identify at-risk customers before they leave, allowing the marketing team to target them with personalized retention campaigns and optimize overall marketing spend.
#
# 3. Project Objectives — What Success Looks Like
# Success looks like having a functional classification model that accurately flags 'at-risk' customers. A successful outcome will allow us to extract actionable insights about the key factors driving churn (such as contract type or monthly charges). These insights can be used to guide data-driven marketing decisions.
#
# 4. Dataset Details
#
# Source: Kaggle - IBM Telco Customer Churn Dataset.
#
# Size: 10 selected features, 7,043 rows (filtered to meet the milestone requirement).
#
# Target Variable: 'Churn' (Yes/No).

# %%
# Import the pandas library
import pandas as pd

# Load the Telco Customer Churn dataset
df = pd.read_csv('WA_Fn-UseC_-Telco-Customer-Churn.csv')

# Select exactly 10 features to meet the milestone requirement (5 to 15 features)
selected_features = [
    "customerID",
    "tenure",
    "Contract",
    "PaperlessBilling",
    "PaymentMethod",
    "MonthlyCharges",
    "TotalCharges",
    "InternetService",
    "TechSupport",
    "Churn"
]

# Create a new dataframe containing only the selected features
df_filtered = df[selected_features]

# Display the first 5 rows of the dataset to verify it loaded correctly
print("--- First 5 rows of the dataset ---")
print(df_filtered.head())
print("\n")

# Display column information, data types, and non-null values
print("--- Dataset Information ---")
print(df_filtered.info())
print("\n")

# Provide a quick statistical summary of the numerical columns
print("--- Statistical Summary ---")
print(df_filtered.describe())
# Out:
# --- First 5 rows of the dataset ---
#    customerID  tenure        Contract PaperlessBilling  \
# 0  7590-VHVEG       1  Month-to-month              Yes
# 1  5575-GNVDE      34        One year               No
# 2  3668-QPYBK       2  Month-to-month              Yes
# 3  7795-CFOCW      45        One year               No
# 4  9237-HQITU       2  Month-to-month              Yes
#
#                PaymentMethod  MonthlyCharges TotalCharges InternetService  \
# 0           Electronic check           29.85        29.85             DSL
# 1               Mailed check           56.95       1889.5             DSL
# 2               Mailed check           53.85       108.15             DSL
# 3  Bank transfer (automatic)           42.30      1840.75             DSL
# 4           Electronic check           70.70       151.65     Fiber optic
#
#   TechSupport Churn
# 0          No    No
# 1          No    No
# 2          No   Yes
# 3         Yes    No
# 4          No   Yes
#
#
# ...
